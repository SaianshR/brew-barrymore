# %% [markdown]
# # Task H - Lift Analysis
# <p>Author: Samuel D'Avila</p>

# %%
# Importing libraries

import numpy as np
import pandas as pd
import ReferenceArchitecture as ra

# %%
# Import CSV scores
# can do check if for file if I have more time
df_sim_scores = pd.read_csv('similarity_scores.csv')

# %%
df_sim_scores # List the product name, the review for a given product and its similarity score for that product.
# Out:
#       Unnamed: 0                 product_name  \
# 0              1  Kentucky Brunch Brand Stout
# 1              2  Kentucky Brunch Brand Stout
# 2              3  Kentucky Brunch Brand Stout
# 3              4  Kentucky Brunch Brand Stout
# 4              5  Kentucky Brunch Brand Stout
# ...          ...                          ...
# 2508        2509                 Coolship Red
# 2509        2510                 Coolship Red
# 2510        2511                 Coolship Red
# 2511        2512                 Coolship Red
# 2512        2513                 Coolship Red
#
#                                          product_review  similarity_score
# 0     I didnt think i was going to give it a perfect...          0.035921
# 1     So I just read a review that called the legend...          0.019702
# 2     2021 vintage bottle 79\n\nHoly Fucking Shit KB...          0.110674
# 3     Celebrating my buddy Rug with his 1000th beer ...          0.071157
# 4     Thick and syrupy pour mocha head Aroma is booz...          0.063246
# ...                                                 ...               ...
# 2508  Very interesting and complex ale First this is...          0.000000
# 2509  Appearance  The beer was pinkish red is color ...          0.000000
# 2510  Look beautiful opaque garnet red Soft white he...          0.000000
# 2511  Caged and corked bottle dated dec32020 and ope...          0.000000
# 2512  I want more funk The raspberry character is bi...          0.000000
#
# [2513 rows x 4 columns]

# %%
# Creates a new column that concatenates the string values of the product name and product review columns
df_sim_scores['name_review'] = df_sim_scores['product_name'] + " " + df_sim_scores['product_review']
df_sim_scores # Display the new table
# Out:
#       Unnamed: 0                 product_name  \
# 0              1  Kentucky Brunch Brand Stout
# 1              2  Kentucky Brunch Brand Stout
# 2              3  Kentucky Brunch Brand Stout
# 3              4  Kentucky Brunch Brand Stout
# 4              5  Kentucky Brunch Brand Stout
# ...          ...                          ...
# 2508        2509                 Coolship Red
# 2509        2510                 Coolship Red
# 2510        2511                 Coolship Red
# 2511        2512                 Coolship Red
# 2512        2513                 Coolship Red
#
#                                          product_review  similarity_score  \
# 0     I didnt think i was going to give it a perfect...          0.035921
# 1     So I just read a review that called the legend...          0.019702
# 2     2021 vintage bottle 79\n\nHoly Fucking Shit KB...          0.110674
# 3     Celebrating my buddy Rug with his 1000th beer ...          0.071157
# 4     Thick and syrupy pour mocha head Aroma is booz...          0.063246
# ...                                                 ...               ...
# 2508  Very interesting and complex ale First this is...          0.000000
# 2509  Appearance  The beer was pinkish red is color ...          0.000000
# 2510  Look beautiful opaque garnet red Soft white he...          0.000000
# 2511  Caged and corked bottle dated dec32020 and ope...          0.000000
# 2512  I want more funk The raspberry character is bi...          0.000000
#
#                                             name_review
# 0     Kentucky Brunch Brand Stout I didnt think i wa...
# 1     Kentucky Brunch Brand Stout So I just read a r...
# 2     Kentucky Brunch Brand Stout 2021 vintage bottl...
# 3     Kentucky Brunch Brand Stout Celebrating my bud...
# 4     Kentucky Brunch Brand Stout Thick and syrupy p...
# ...                                                 ...
# 2508  Coolship Red Very interesting and complex ale ...
# 2509  Coolship Red Appearance  The beer was pinkish ...
# 2510  Coolship Red Look beautiful opaque garnet red ...
# 2511  Coolship Red Caged and corked bottle dated dec...
# 2512  Coolship Red I want more funk The raspberry ch...
#
# [2513 rows x 5 columns]

# %%
# Generate a lift table and a dataframe of the lift values
beer_attributes = ['chocolate', 'dark', 'sweet', 'bourbon'] # The attributes of interest found from our frequencies

all_beer_names = [i for i in np.unique(df_sim_scores['product_name'])] # Get a list of all unique beers
rand_beers = [all_beer_names[np.random.randint(0,len(all_beer_names))] for i in range(0, 10, 1)] # Randomly select 10 beers 

beer_attributes_names = beer_attributes # Repackaging beer attributes as new list
for i in rand_beers: # For every beer of the randomly selected 10 beers...
    beer_attributes_names.append(i) # ...add that beer into the same list as the beer attributes

col = 'name_review' # Column that contains the product name and product review
lift_table, lift_dict_values = ra.lift_ratio(index=beer_attributes_names, data=df_sim_scores, capture_column=col) # Create the lift table and dataframe of lift values

# %%
lift_table # Display the lift table
# Out:
# <style type="text/css">
# #T_870f9_row0_col0, #T_870f9_row1_col1, #T_870f9_row2_col2, #T_870f9_row3_col3, #T_870f9_row4_col4, #T_870f9_row5_col5, #T_870f9_row6_col6, #T_870f9_row7_col7, #T_870f9_row8_col8, #T_870f9_row9_col9, #T_870f9_row10_col10, #T_870f9_row11_col11, #T_870f9_row12_col12, #T_870f9_row13_col13 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_870f9_row0_col1, #T_870f9_row0_col2, #T_870f9_row0_col3, #T_870f9_row0_col8, #T_870f9_row0_col9, #T_870f9_row0_col13, #T_870f9_row2_col5, #T_870f9_row2_col10, #T_870f9_row3_col0, #T_870f9_row3_col4, #T_870f9_row3_col6, #T_870f9_row3_col7, #T_870f9_row3_col11, #T_870f9_row3_col12 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_870f9_row0_col4 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_870f9_row0_col5, #T_870f9_row0_col10, #T_870f9_row1_col5, #T_870f9_row1_col9, #T_870f9_row1_col10, #T_870f9_row3_col5, #T_870f9_row3_col9, #T_870f9_row3_col10, #T_870f9_row4_col2, #T_870f9_row4_col5, #T_870f9_row4_col6, #T_870f9_row4_col7, #T_870f9_row4_col8, #T_870f9_row4_col9, #T_870f9_row4_col10, #T_870f9_row4_col11, #T_870f9_row4_col12, #T_870f9_row4_col13, #T_870f9_row5_col0, #T_870f9_row5_col1, #T_870f9_row5_col3, #T_870f9_row5_col4, #T_870f9_row5_col6, #T_870f9_row5_col7, #T_870f9_row5_col8, #T_870f9_row5_col9, #T_870f9_row5_col10, #T_870f9_row5_col11, #T_870f9_row5_col12, #T_870f9_row5_col13, #T_870f9_row6_col4, #T_870f9_row6_col5, #T_870f9_row6_col7, #T_870f9_row6_col8, #T_870f9_row6_col9, #T_870f9_row6_col10, #T_870f9_row6_col11, #T_870f9_row6_col12, #T_870f9_row6_col13, #T_870f9_row7_col4, #T_870f9_row7_col5, #T_870f9_row7_col6, #T_870f9_row7_col8, #T_870f9_row7_col9, #T_870f9_row7_col10, #T_870f9_row7_col11, #T_870f9_row7_col12, #T_870f9_row7_col13, #T_870f9_row8_col4, #T_870f9_row8_col5, #T_870f9_row8_col6, #T_870f9_row8_col7, #T_870f9_row8_col9, #T_870f
">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_870f9_level0_col0" class="col_heading level0 col0" >chocolate</th>
#       <th id="T_870f9_level0_col1" class="col_heading level0 col1" >dark</th>
#       <th id="T_870f9_level0_col2" class="col_heading level0 col2" >sweet</th>
#       <th id="T_870f9_level0_col3" class="col_heading level0 col3" >bourbon</th>
#       <th id="T_870f9_level0_col4" class="col_heading level0 col4" >Coconut B-Bomb</th>
#       <th id="T_870f9_level0_col5" class="col_heading level0 col5" >Society & Solitude #5</th>
#       <th id="T_870f9_level0_col6" class="col_heading level0 col6" >Bourbon County Brand Stout</th>
#       <th id="T_870f9_level0_col7" class="col_heading level0 col7" >Assassin</th>
#       <th id="T_870f9_level0_col8" class="col_heading level0 col8" >Kentucky Brunch Brand Stout</th>
#       <th id="T_870f9_level0_col9" class="col_heading level0 col9" >Rare Scooop</th>
#       <th id="T_870f9_level0_col10" class="col_heading level0 col10" >Adios Ghost</th>
#       <th id="T_870f9_level0_col11" class="col_heading level0 col11" >Hellaboozie (Bourbon Barrel Aged Dark Lord Imperial Stout)</th>
#       <th id="T_870f9_level0_col12" class="col_heading level0 col12" >Bourbon Paradise</th>
#       <th id="T_870f9_level0_col13" class="col_heading level0 col1

# %%
lift_dict_values # Display the dataframe of the lift values

# %%
rando_beer = lift_dict_values.columns[np.random.randint(4, len(lift_dict_values))] # Select a random beer from the 10 randomly selected beers
rando_beer

# %%
lift_dict_values.columns # List the attritbutes and 10 randomly chosen beers

# %%
diff = []   # List to contain differences of summed lift values
idx = []    # List to store name of the beer
for i in lift_dict_values.columns[4:]: # For beer in list of 10 randomly selected beers...
    if i == rando_beer: # if the beer picked is our randomly selected beer
        continue # Iterate to the next beer
    # Take the difference between the chosen beer and one of the 9 remaining beers for each attribute
    series = abs(lift_dict_values[rando_beer][:4]) - abs(lift_dict_values[i][:4]) 
    # Append the sum of lift values and the name of the beer compared to the chosen beer
    val = sum(series.values) 
    diff.append(val)
    idx.append(i)

# %%
most_sim = pd.Series(diff, index=idx) # Create a new pandas series that contains comparison
most_sim # Display the difference scores

# %% [markdown]
# For our code, we randomly select 10 beers and then randomly select 1 beer from those ten. This random beer is compared to others through a taking the lift values across the 4 attributes (in our case: "chocolate," "dark," "sweet," "bourbon") and summing the whole series of values for each beer (we now have 10 beers with a 1 value that represents the sum of their lift values on their attributes). We then take the difference between the combined lift for the selected beer and the remaining beers. The closer the remaining values are to zero, the more similar that one of the nine beers is the selected beer. During the code's testing, we had the following 10 beers:
#     'Atrial Rubicite',
#     'The Adjunct Trail - Bourbon Barrel-Aged',
#     'Double Dry Hopped Double Citra Daydream',
#     'Clare's Thirsty Ale',
#     'Coconut B-Bomb',
#     'Affogato - Bourbon Barrel-Aged',
#     'Juice Machine',
#     'Henna: Barrel-Aged Double Rainbow',
#     'JJJuliusss!'.
# The randomly selected beer was the 'Affogato - Bourbon Barrel-Aged' and the following lift differences were calculated for each beer:
# Atrial Rubicite                            4.061
# The Adjunct Trail - Bourbon Barrel-Aged    4.061
# Double Dry Hopped Double Citra Daydream    4.061
# Clare's Thirsty Ale                       -5.639
# Coconut B-Bomb                            -2.932
# Juice Machine                              1.346
# Henna: Barrel-Aged Double Rainbow         -3.476
# JJJuliusss!                               -2.942
#
# From these values we can say that the 'Juice Machine' is most similar to 'Affogato - Bourbon Barrel-Aged' beer.
